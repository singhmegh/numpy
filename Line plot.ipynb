# %%
import matplotlib.pyplot as plt

x=["Day1","Day2","Day3","Day4","Day5"]
y=[300,340,250,200,400]
y1=[500,765,366,210,350]

plt.plot(x,y,marker ="*",ls="--",color="orange",label="week1")
plt.plot(x,y1,marker ="o",ls=":",color="blue",label="week2")
plt.legend()
#plt.plot(range(len(x)),y)
#plt.xticks(range(len(x)),x)
plt.show()
